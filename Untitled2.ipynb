# %% [markdown]
# <a href="https://colab.research.google.com/github/seunghee-data/aiffel-study/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#요구사항
#1. 숫자 5개 설정
# 1-1. 난수로 설정해야겠다.
# 1-2. 난수 뽑으면 앞에것들 중복 확인 후 확정
# 1-3. 5자리 되면 종료 (카운트할 것)

import random

answer_count = 0
answer_list = []


while True :
    answer_random = str(random.randint(0,9))

    if not (answer_random in answer_list) :
        answer_list.append(answer_random)
        answer_count += 1

    if answer_count == 5 :
      # print("생성된 정답")
      # print(answer_list)
      break




#2. 숫자 5개 입력받기

# 2-1 input으로 입력받아야겠다



#입력 무한루프 지점


while True :

    print("숫자야구겜!!")
    numbers = str(input("다섯자리 숫자를 입력하세요"))

    # 2-2 슬라이싱 해야겠다

    numbers_list = []
    numbers_count = 0
    for i in numbers :
        numbers_list.append(i)
        # print(i)
        numbers_count += 1


    # print(numbers_count)
    # print(numbers_list)




    # 2-3 다섯자리 미만, 초과도 거부시켜야겠다
    # 2-4 중복 숫자 입력은 거부시켜야겠다 (다시 입력하세요)





    #3. 숫자 위치 확인 + 존재 여부 확인


    result_strike = 0
    result_ball = 0

    try_count = 0



    for i in range(0, 5) :
        # print("인덱스")
        # print(i)
        if numbers_list[i] == answer_list[i] :
            result_strike += 1
            continue

        for k in range(0, 5) :
            if numbers_list[i] == answer_list[k] :
                result_ball += 1



    #4. 결과에 따라 출력 및 반복 (S, B)

    print("스트라이크: " + str(result_strike))
    print("볼: " + str(result_ball))


    #5. 전부 맞췄으면 종료 및 정답 공개 (= 스트라이크5)


    if result_strike == 5 :
        print("정답 공개")
        print(answer_list)
        break
# Out:
# 다섯자리 숫자를 입력하세요76482
# 스트라이크: 0
# 볼: 1
