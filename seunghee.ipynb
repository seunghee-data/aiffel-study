# %% [markdown]
# # 🚀 Seunghee Data의 1주차 환경 구축 일지
#
# ## 1. Git & GitHub 설정 요약
#
# - **Username (ID):** `seunghee-data`
# - **Author Name:** `Seunghee Son`
# - **핵심:** `git push`를 위해 토큰(Token)을 사용하는 법을 익힘.
